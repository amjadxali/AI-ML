# %% [markdown]
# # Week 2 Assignment: CIFAR-10 Autoencoder
#
# For this week, you will create a convolutional autoencoder for the [CIFAR10](https://www.tensorflow.org/datasets/catalog/cifar10) dataset. You are free to choose the architecture of your autoencoder provided that the output image has the same dimensions as the input image.
#
# After training, your model should meet loss and accuracy requirements when evaluated with the test dataset. You will then download the model and upload it in the classroom for grading.
#
# Let's begin!

# %% [markdown]
# ***Important:*** *This colab notebook has read-only access so you won't be able to save your changes. If you want to save your work periodically, please click `File -> Save a Copy in Drive` to create a copy in your account, then work from there.*

# %% [markdown]
# ## Imports

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

from keras.models import Sequential

# %% [markdown]
# ## Load and prepare the dataset
#
# The [CIFAR 10](https://www.tensorflow.org/datasets/catalog/cifar10) dataset already has train and test splits and you can use those in this exercise. Here are the general steps:
#
# * Load the train/test split from TFDS. Set `as_supervised` to `True` so it will be convenient to use the preprocessing function we provided.
# * Normalize the pixel values to the range [0,1], then return `image, image` pairs for training instead of `image, label`. This is because you will check if the output image is successfully regenerated after going through your autoencoder.
# * Shuffle and batch the train set. Batch the test set (no need to shuffle).

# %%
# preprocessing function
def map_image(image, label):
  image = tf.cast(image, dtype=tf.float32)
  image = image / 255.0

  return image, image # dataset label is not used. replaced with the same image input.

# parameters
BATCH_SIZE = 128
SHUFFLE_BUFFER_SIZE = 1024


### START CODE HERE (Replace instances of `None` with your code) ###

# use tfds.load() to fetch the 'train' split of CIFAR-10
train_dataset = tfds.load('cifar10', as_supervised=True, split="train")

# preprocess the dataset with the `map_image()` function above
train_dataset = train_dataset.map(map_image)

# shuffle and batch the dataset
train_dataset = train_dataset.shuffle(SHUFFLE_BUFFER_SIZE).batch(BATCH_SIZE)


# use tfds.load() to fetch the 'test' split of CIFAR-10
test_dataset = tfds.load('cifar10', as_supervised=True, split="test")

# preprocess the dataset with the `map_image()` function above
test_dataset = test_dataset.map(map_image)

# batch the dataset
test_dataset = test_dataset.batch(BATCH_SIZE)

### END CODE HERE ###
# Out:
# WARNING:absl:Variant folder /root/tensorflow_datasets/cifar10/3.0.2 has no dataset_info.json
# Downloading and preparing dataset Unknown size (download: Unknown size, generated: Unknown size, total: Unknown size) to /root/tensorflow_datasets/cifar10/3.0.2...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/cifar10/incomplete.KFYOR8_3.0.2/cifar10-train.tfrecord*...:   0%|         …
# Generating test examples...: 0 examples [00:00, ? examples/s]
# Shuffling /root/tensorflow_datasets/cifar10/incomplete.KFYOR8_3.0.2/cifar10-test.tfrecord*...:   0%|          …
# Dataset cifar10 downloaded and prepared to /root/tensorflow_datasets/cifar10/3.0.2. Subsequent calls will reuse this data.

# %% [markdown]
# ## Build the Model
#
# Create the autoencoder model. As shown in the lectures, you will want to downsample the image in the encoder layers then upsample it in the decoder path. Note that the output layer should be the same dimensions as the original image. Your input images will have the shape `(32, 32, 3)`. If you deviate from this, your model may not be recognized by the grader and may fail.
#
# We included a few hints to use the Sequential API below but feel free to remove it and use the Functional API just like in the ungraded labs if you're more comfortable with it. Another reason to use the latter is if you want to visualize the encoder output. As shown in the ungraded labs, it will be easier to indicate multiple outputs with the Functional API. That is not required for this assignment though so you can just stack layers sequentially if you want a simpler solution.

# %%
# suggested layers to use. feel free to add or remove as you see fit.
from keras.layers import Conv2D, UpSampling2D

# use the Sequential API (you can remove if you want to use the Functional API)
# model = Sequential()

### START CODE HERE ###
# use `model.add()` to add layers (if using the Sequential API)
inputs = tf.keras.layers.Input(shape=(32, 32, 3,))
conv_1 = tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(inputs)
max_pool_1 = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(conv_1)
conv_2 = tf.keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(max_pool_1)
max_pool_2 = tf.keras.layers.MaxPooling2D(pool_size=(2,2))(conv_2)

bottle_neck = tf.keras.layers.Conv2D(filters=256, kernel_size=(3,3), activation='relu', padding='same')(max_pool_2)
# encoder_visualization = tf.keras.layers.Conv2D(filters=1, kernel_size=(3,3), activation='sigmoid', padding='same')(bottle_neck)

conv_3 = tf.keras.layers.Conv2D(filters=128, kernel_size=(3,3), activation='relu', padding='same')(bottle_neck)
up_sample_1 = tf.keras.layers.UpSampling2D(size=(2,2))(conv_3)
conv_4 = tf.keras.layers.Conv2D(filters=64, kernel_size=(3,3), activation='relu', padding='same')(up_sample_1)
up_sample_2 = tf.keras.layers.UpSampling2D(size=(2,2))(conv_4)
decoder_output = tf.keras.layers.Conv2D(filters=3, kernel_size=(3,3), activation='sigmoid', padding='same')(up_sample_2)


model = tf.keras.Model(inputs =inputs, outputs=decoder_output)
# encoder_model = tf.keras.Model(inputs=inputs, outputs=encoder_visualization)


### END CODE HERE ###

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)        │ (None, 32, 32, 3)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 32, 64)     │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 16, 16, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 16, 16, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 8, 8, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 8, 8, 256)      │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 8, 8, 128)      │       295,040 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d (UpSampling2D)    │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 16, 16, 64)     │        73,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ up_sampling2d_1 (UpSampling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 32, 32, 3)      │         1,731 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 741,379 (2.83 MB)
#  Trainable params: 741,379 (2.83 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Configure training parameters
#
# We have already provided the optimizer, metrics, and loss in the code below.

# %%
# Please do not change the model.compile() parameters
model.compile(optimizer='adam', metrics=['accuracy'], loss='mean_squared_error')

# %% [markdown]
# ## Training
#
# You can now use [model.fit()](https://keras.io/api/models/model_training_apis/#fit-method) to train your model. You will pass in the `train_dataset` and you are free to configure the other parameters. As with any training, you should observe the loss generally going down and the accuracy going up at each epoch. If not, please revisit the previous sections to find possible bugs.
#
# *Note: If you get a `dataset length is infinite` error. Please check how you defined `train_dataset`. You might have included a [method that repeats the dataset indefinitely](https://www.tensorflow.org/api_docs/python/tf/data/Dataset#repeat).*

# %%
# parameters
train_steps = len(train_dataset) // BATCH_SIZE
val_steps = len(test_dataset) // BATCH_SIZE

### START CODE HERE ###
model.fit(train_dataset, steps_per_epoch=train_steps, validation_data=test_dataset, validation_steps=val_steps, epochs=100)
### END CODE HERE ###
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 35s 15s/step - accuracy: 0.4068 - loss: 0.0623 - val_accuracy: 0.5027 - val_loss: 0.0614
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.5142 - loss: 0.0640 - val_accuracy: 0.4383 - val_loss: 0.0503
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.3764 - loss: 0.0549 - val_accuracy: 0.3948 - val_loss: 0.0514
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.4351 - loss: 0.0518 - val_accuracy: 0.3327 - val_loss: 0.0431
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.3397 - loss: 0.0444 - val_accuracy: 0.3536 - val_loss: 0.0412
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 30s 14s/step - accuracy: 0.3769 - loss: 0.0389 - val_accuracy: 0.3912 - val_loss: 0.0346
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.3678 - loss: 0.0353 - val_accuracy: 0.3972 - val_loss: 0.0305
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.4281 - loss: 0.0304 - val_accuracy: 0.5026 - val_loss: 0.0318
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.5270 - loss: 0.0304 - val_accuracy: 0.5190 - val_loss: 0.0279
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.5242 - loss: 0.0256 - val_accuracy: 0.4820 - val_loss: 0.0238
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.4847 - loss: 0.0231 - val_accuracy: 0.5526 - val_loss: 0.0213
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.5421 - loss: 0.0209 - val_accuracy: 0.6284 - val_loss: 0.0202
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.6406 - loss: 0.0192 - val_accuracy: 0.6082 - val_loss: 0.0169
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 31s 15s/step - accuracy: 0.6185 - loss: 0.0178 - val_accuracy: 0.6462 - val_loss: 0.0169
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 30s 14s/step - accuracy: 0.6371 - loss: 0.0166 - val_accuracy: 0.6380 - val_loss: 0.0170
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.6252 - loss: 0.0169 - val_accuracy: 0.6292 - val_loss: 0.0148
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.6291 - loss: 0.0153 - val_accuracy: 0.6100 - val_loss: 0.0154
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.6213 - loss: 0.0154 - val_accuracy: 0.6496 - val_loss: 0.0133
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.6368 - loss: 0.0142 - val_accuracy: 0.6439 - val_loss: 0.0133
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.6369 - loss: 0.0133 - val_accuracy: 0.6348 - val_loss: 0.0125
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 30s 14s/step - accuracy: 0.6354 - loss: 0.0126 - val_accuracy: 0.6416 - val_loss: 0.0120
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.6473 - loss: 0.0121 - val_accuracy: 0.6725 - val_loss: 0.0116
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.6555 - loss: 0.0115 - val_accuracy: 0.6198 - val_loss: 0.0113
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.6408 - loss: 0.0115 - val_accuracy: 0.6811 - val_loss: 0.0144
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.6583 - loss: 0.0134 - val_accuracy: 0.6609 - val_loss: 0.0118
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.6693 - loss: 0.0111 - val_accuracy: 0.6911 - val_loss: 0.0117
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 14s/step - accuracy: 0.6984 - loss: 0.0116 - val_accuracy: 0.6926 - val_loss: 0.0107
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7051 - loss: 0.0104 - val_accuracy: 0.7090 - val_loss: 0.0098
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7132 - loss: 0.0096 - val_accuracy: 0.7088 - val_loss: 0.0100
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.6956 - loss: 0.0101 - val_accuracy: 0.7250 - val_loss: 0.0096
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7235 - loss: 0.0094 - val_accuracy: 0.6910 - val_loss: 0.0092
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.6972 - loss: 0.0088 - val_accuracy: 0.7339 - val_loss: 0.0088
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7272 - loss: 0.0088 - val_accuracy: 0.7414 - val_loss: 0.0088
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.7355 - loss: 0.0086 - val_accuracy: 0.7367 - val_loss: 0.0083
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7397 - loss: 0.0081 - val_accuracy: 0.7397 - val_loss: 0.0085
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7357 - loss: 0.0088 - val_accuracy: 0.7245 - val_loss: 0.0110
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7312 - loss: 0.0101 - val_accuracy: 0.7549 - val_loss: 0.0094
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7275 - loss: 0.0095 - val_accuracy: 0.7482 - val_loss: 0.0093
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 14s/step - accuracy: 0.7568 - loss: 0.0089 - val_accuracy: 0.7459 - val_loss: 0.0088
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.7521 - loss: 0.0087 - val_accuracy: 0.7540 - val_loss: 0.0079
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7657 - loss: 0.0078 - val_accuracy: 0.7501 - val_loss: 0.0076
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 13s/step - accuracy: 0.7482 - loss: 0.0077 - val_accuracy: 0.7622 - val_loss: 0.0076
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.7646 - loss: 0.0076 - val_accuracy: 0.7612 - val_loss: 0.0077
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7544 - loss: 0.0075 - val_accuracy: 0.7534 - val_loss: 0.0074
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7610 - loss: 0.0077 - val_accuracy: 0.7623 - val_loss: 0.0071
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7708 - loss: 0.0071 - val_accuracy: 0.7678 - val_loss: 0.0070
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.7712 - loss: 0.0072 - val_accuracy: 0.7706 - val_loss: 0.0069
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7643 - loss: 0.0070 - val_accuracy: 0.7747 - val_loss: 0.0070
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7800 - loss: 0.0066 - val_accuracy: 0.7693 - val_loss: 0.0068
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7650 - loss: 0.0069 - val_accuracy: 0.7734 - val_loss: 0.0071
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7900 - loss: 0.0071 - val_accuracy: 0.7664 - val_loss: 0.0066
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7717 - loss: 0.0064 - val_accuracy: 0.7506 - val_loss: 0.0066
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.7548 - loss: 0.0064 - val_accuracy: 0.7587 - val_loss: 0.0065
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7846 - loss: 0.0064 - val_accuracy: 0.7593 - val_loss: 0.0064
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7850 - loss: 0.0062 - val_accuracy: 0.7498 - val_loss: 0.0070
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7420 - loss: 0.0084 - val_accuracy: 0.7597 - val_loss: 0.0103
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 14s/step - accuracy: 0.7776 - loss: 0.0087 - val_accuracy: 0.7475 - val_loss: 0.0079
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7502 - loss: 0.0080 - val_accuracy: 0.7753 - val_loss: 0.0067
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7708 - loss: 0.0072 - val_accuracy: 0.7666 - val_loss: 0.0077
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7638 - loss: 0.0075 - val_accuracy: 0.7348 - val_loss: 0.0066
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7519 - loss: 0.0067 - val_accuracy: 0.7827 - val_loss: 0.0067
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7825 - loss: 0.0066 - val_accuracy: 0.7743 - val_loss: 0.0064
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.7931 - loss: 0.0061 - val_accuracy: 0.7512 - val_loss: 0.0063
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7540 - loss: 0.0062 - val_accuracy: 0.7795 - val_loss: 0.0062
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7592 - loss: 0.0063 - val_accuracy: 0.7819 - val_loss: 0.0063
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7711 - loss: 0.0066 - val_accuracy: 0.7798 - val_loss: 0.0061
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7841 - loss: 0.0060 - val_accuracy: 0.7539 - val_loss: 0.0060
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7716 - loss: 0.0062 - val_accuracy: 0.7690 - val_loss: 0.0059
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.7687 - loss: 0.0058 - val_accuracy: 0.7902 - val_loss: 0.0058
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7731 - loss: 0.0059 - val_accuracy: 0.7945 - val_loss: 0.0057
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7845 - loss: 0.0056 - val_accuracy: 0.7916 - val_loss: 0.0057
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7961 - loss: 0.0054 - val_accuracy: 0.7858 - val_loss: 0.0057
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7816 - loss: 0.0055 - val_accuracy: 0.7830 - val_loss: 0.0055
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.8002 - loss: 0.0055 - val_accuracy: 0.7856 - val_loss: 0.0057
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7922 - loss: 0.0058 - val_accuracy: 0.7858 - val_loss: 0.0056
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7953 - loss: 0.0054 - val_accuracy: 0.7759 - val_loss: 0.0056
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7881 - loss: 0.0059 - val_accuracy: 0.7419 - val_loss: 0.0068
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7714 - loss: 0.0066 - val_accuracy: 0.7562 - val_loss: 0.0055
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7778 - loss: 0.0054 - val_accuracy: 0.7639 - val_loss: 0.0054
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7719 - loss: 0.0059 - val_accuracy: 0.7810 - val_loss: 0.0055
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7756 - loss: 0.0057 - val_accuracy: 0.7933 - val_loss: 0.0055
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 13s/step - accuracy: 0.7940 - loss: 0.0054 - val_accuracy: 0.7985 - val_loss: 0.0054
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 14s/step - accuracy: 0.7903 - loss: 0.0052 - val_accuracy: 0.7981 - val_loss: 0.0053
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7875 - loss: 0.0055 - val_accuracy: 0.7950 - val_loss: 0.0054
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.7939 - loss: 0.0054 - val_accuracy: 0.7860 - val_loss: 0.0054
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 14s/step - accuracy: 0.7852 - loss: 0.0053 - val_accuracy: 0.7859 - val_loss: 0.0052
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.7886 - loss: 0.0055 - val_accuracy: 0.7945 - val_loss: 0.0056
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 13s/step - accuracy: 0.7787 - loss: 0.0057 - val_accuracy: 0.7930 - val_loss: 0.0051
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7927 - loss: 0.0051 - val_accuracy: 0.7836 - val_loss: 0.0052
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.7867 - loss: 0.0050 - val_accuracy: 0.7865 - val_loss: 0.0050
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 13s/step - accuracy: 0.8007 - loss: 0.0050 - val_accuracy: 0.7933 - val_loss: 0.0050
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7942 - loss: 0.0051 - val_accuracy: 0.7838 - val_loss: 0.0049
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 28s 13s/step - accuracy: 0.7907 - loss: 0.0049 - val_accuracy: 0.7781 - val_loss: 0.0050
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7794 - loss: 0.0051 - val_accuracy: 0.7900 - val_loss: 0.0064
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7936 - loss: 0.0071 - val_accuracy: 0.7714 - val_loss: 0.0053
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.7870 - loss: 0.0054 - val_accuracy: 0.7928 - val_loss: 0.0051
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 29s 14s/step - accuracy: 0.7780 - loss: 0.0054 - val_accuracy: 0.7891 - val_loss: 0.0051
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 31s 15s/step - accuracy: 0.7714 - loss: 0.0051 - val_accuracy: 0.7969 - val_loss: 0.0050
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.8025 - loss: 0.0052 - val_accuracy: 0.7848 - val_loss: 0.0050
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 45s 22s/step - accuracy: 0.7730 - loss: 0.0048 - val_accuracy: 0.7856 - val_loss: 0.0049

# %% [markdown]
# ## Model evaluation
#
# You can use this code to test your model locally before uploading to the grader. To pass, your model needs to satisfy these two requirements:
#
# * loss must be less than 0.01
# * accuracy must be greater than 0.6

# %%
result = model.evaluate(test_dataset, steps=10)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 3s 313ms/step - accuracy: 0.7828 - loss: 0.0049

# %% [markdown]
# If you did some visualization like in the ungraded labs, then you might see something like the gallery below. This part is not required.

# %% [markdown]
# <img src="https://storage.googleapis.com/tensorflow-3-public/assets/images/autoencoder.png" width="75%" height="75%"/>

# %% [markdown]
# ## Save the Model
#
# Once you're satisfied with the results, you can save your model and upload it to the grader in Coursera. Please run all succeeding cells to ensure that you will have a gradable submission. Otherwise, you might get this error message:
#
# `There was a problem grading your submission. Check stderr for more details.`
#
# First, save the model file in your Colab workspace.

# %%
# Save the model you just trained
model.save("mymodel.keras")

# %%
# You can also use this cell as a shortcut for downloading your model
from google.colab import files
files.download("mymodel.keras")

# %% [markdown]
# **Congratulations on completing this week's assignment!**
